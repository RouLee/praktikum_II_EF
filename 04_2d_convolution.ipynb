# %% [markdown]
# # Convolution Programmieren

# %% [markdown]
# <div style="padding: 5px; border: 5px solid #a10000ff;">
#
# **Hinweis:** In den Codezellen sind jeweils einige Codeteile nicht programmiert. Diesen Code müssen Sie ergänzen. Die jeweiligen Stellen sind mit einem Kommentar und dem Keyword **TODO** vermerkt und z.T. Stellen mit ... markiert.
#
# Ausserdem gibt es einige assert Statements. Diese geben einen Fehler aus, sollte etwas bei Ihrer Programmierung nicht korrekt sein.

# %%
import PIL.Image as Image
import matplotlib.pyplot as plt
import numpy as np

# Wir lesen zuerst das Bild ein und konvertieren es in Graustufen
image = Image.open("images/dog.jpg").convert("L")

# Dann wandeln wir das Bild in ein NumPy-Array um und visualisieren es mit Matplotlib
image_array = np.array(image)
plt.imshow(image_array, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Aufgabe 1

# %% [markdown]
# Vervollständigen Sie das Programm für die Convolution Operation.
#
# Zur Erinnerung, der Filter-Kernel wird jeweils über das Bild geschoben und der Wert resultierend aus der Convolutionoperation im zentralen Pixel niedergeschrieben.

# %%
#TODO definieren Sie einen Kernel als Numpy-Array. Wählen Sie entweder einen 3x3 oder 5x5 Kernel.

kernel = np.array(...)

assert kernel.shape[0] == kernel.shape[1], "Kernel muss quadratisch sein"

# %%
# Wir speichern nun die Kernel Grösse in einer Variable
kernel_size = kernel.shape[0]

# TODO erstellen Sie ein Numpy-Array für das konvolvierte Bild mit der gleichen Form wie das Originalbild. Tipp: Nutzen Sie np.zeros_like
image_convolved = ...
# TODO Wir möchten, dass das Bild gleich gross bleibt nach der Convolution-Operation. Daher müssen wir das Bild mit Nullen auffüllen (padding). Nutzen Sie np.pad, um das Bild mit einer Breite von kernel_size//2 aufzufüllen.
image_padded = ...


# TODO implementieren Sie hier die 2D-Convolution Operation mit zwei for-Schleifen über die Höhe und Breite des Bildes.
# Nutzen Sie array slicing, um den entsprechenden Bildausschnitt zu extrahieren und die Convolution mit dem Kernel durchzuführen.
# Das Resultat soll jeweils in das image_convolved Array geschrieben werden.

for ...


# Wir visualisieren nun das Ergebnis.
plt.imshow(image_convolved, cmap='gray')
plt.axis('off')
plt.show()
